# %% [markdown]
# # Сбор скаченных данных в формате .shp с geofabrik

# %%
import geopandas as gpd
import os, sys
import pandas as pd
import pygeos

# %%
#регионы
region = ['Central_Federal_District',
          'Crimean_Federal_District',
          'Far_Eastern_Federal_District',
          'North_Caucasus_Federal_District',
          'Northwestern_Federal_District',
          'Siberian_Federal_District',
          'South_Federal_District',
          'Ural_Federal_District',
          'Volga_Federal_District']
#названия файлов
l =  ['gis_osm_pois_free_1.shp',
      'gis_osm_buildings_a_free_1.shp',
      'gis_osm_transport_free_1.shp',
      'gis_osm_places_free_1.shp',
      'gis_osm_traffic_free_1.shp']
#gis_osm_pois_free_1.shp - какие то объекты(кафе, банкоматы, банки)
#gis_osm_buildings_a_free_1.shp - строения (квартиры, частные дома)
#gis_osm_transport_free_1.shp -трарспортные объекты (становки, вокзалы, аэропорты)
#gis_osm_places_free_1 -локация
#gis_osm_traffic_free_1.shp -парковки
#название файла - содержимое
sl =  {'gis_osm_pois_free_1.shp': 'pois',
      'gis_osm_buildings_a_free_1.shp':'buildings',
      'gis_osm_transport_free_1.shp':'transport',
      'gis_osm_places_free_1.shp':'places',
      'gis_osm_traffic_free_1.shp':'traffic'}

# %%
#названия переменных
list_reg_object=[]
for i in region:
    path = "C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/"+i+'/'
    dirs = os.listdir( path )
    for file in dirs:
        if file in l:
            for k,v in sl.items():
                if k==file:
                    list_reg_object.append(path[54:-1]+"_"+v)

# %%
print(*sorted(list_reg_object), sep = '\n')
# Out:
# Central_Federal_District_buildings
# Central_Federal_District_places
# Central_Federal_District_pois
# Central_Federal_District_traffic
# Central_Federal_District_transport
# Crimean_Federal_District_buildings
# Crimean_Federal_District_places
# Crimean_Federal_District_pois
# Crimean_Federal_District_traffic
# Crimean_Federal_District_transport
# Far_Eastern_Federal_District_buildings
# Far_Eastern_Federal_District_places
# Far_Eastern_Federal_District_pois
# Far_Eastern_Federal_District_traffic
# Far_Eastern_Federal_District_transport
# North_Caucasus_Federal_District_buildings
# North_Caucasus_Federal_District_places
# North_Caucasus_Federal_District_pois
# North_Caucasus_Federal_District_traffic
# North_Caucasus_Federal_District_transport
# Northwestern_Federal_District_buildings
# Northwestern_Federal_District_places
# Northwestern_Federal_District_pois
# Northwestern_Federal_District_traffic
# Northwestern_Federal_District_transport
# Siberian_Federal_District_buildings
# ...

# %%
full_path = []
path = "C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/"
for i in region:
    for j in l:
        full_path.append(path+i+'/'+j)

# %%
print(*sorted(full_path),sep ='\n')
# Out:
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_buildings_a_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_places_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_pois_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_traffic_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_transport_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_buildings_a_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_places_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_pois_free_1.shp
# C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_traffic_free_1.shp
# ...

# %%
#подготовка данных в эксель
Central_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_buildings_a_free_1.shp')
Central_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_places_free_1.shp')
Central_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_pois_free_1.shp')
Central_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_traffic_free_1.shp')
Central_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Central_Federal_District/gis_osm_transport_free_1.shp')
Crimean_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_buildings_a_free_1.shp')
Crimean_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_places_free_1.shp')
Crimean_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_pois_free_1.shp')
Crimean_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_traffic_free_1.shp')
Crimean_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Crimean_Federal_District/gis_osm_transport_free_1.shp')
Far_Eastern_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Far_Eastern_Federal_District/gis_osm_buildings_a_free_1.shp')
Far_Eastern_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Far_Eastern_Federal_District/gis_osm_places_free_1.shp')
Far_Eastern_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Far_Eastern_Federal_District/gis_osm_pois_free_1.shp')
Far_Eastern_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Far_Eastern_Federal_District/gis_osm_traffic_free_1.shp')
Far_Eastern_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Far_Eastern_Federal_District/gis_osm_transport_free_1.shp')
North_Caucasus_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/North_Caucasus_Federal_District/gis_osm_buildings_a_free_1.shp')
North_Caucasus_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/North_Caucasus_Federal_District/gis_osm_places_free_1.shp')
North_Caucasus_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/North_Caucasus_Federal_District/gis_osm_pois_free_1.shp')
North_Caucasus_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/North_Caucasus_Federal_District/gis_osm_traffic_free_1.shp')
North_Caucasus_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/North_Caucasus_Federal_District/gis_osm_transport_free_1.shp')
Northwestern_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Northwestern_Federal_District/gis_osm_buildings_a_free_1.shp')
Northwestern_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Northwestern_Federal_District/gis_osm_places_free_1.shp')
Northwestern_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Northwestern_Federal_District/gis_osm_pois_free_1.shp')
Northwestern_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Northwestern_Federal_District/gis_osm_traffic_free_1.shp')
Northwestern_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Northwestern_Federal_District/gis_osm_transport_free_1.shp')
Siberian_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Siberian_Federal_District/gis_osm_buildings_a_free_1.shp')
Siberian_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Siberian_Federal_District/gis_osm_places_free_1.shp')
Siberian_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Siberian_Federal_District/gis_osm_pois_free_1.shp')
Siberian_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Siberian_Federal_District/gis_osm_traffic_free_1.shp')
Siberian_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Siberian_Federal_District/gis_osm_transport_free_1.shp')
South_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/South_Federal_District/gis_osm_buildings_a_free_1.shp')
South_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/South_Federal_District/gis_osm_places_free_1.shp')
South_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/South_Federal_District/gis_osm_pois_free_1.shp')
South_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/South_Federal_District/gis_osm_traffic_free_1.shp')
South_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/South_Federal_District/gis_osm_transport_free_1.shp')
Ural_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Ural_Federal_District/gis_osm_buildings_a_free_1.shp')
Ural_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Ural_Federal_District/gis_osm_places_free_1.shp')
Ural_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Ural_Federal_District/gis_osm_pois_free_1.shp')
Ural_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Ural_Federal_District/gis_osm_traffic_free_1.shp')
Ural_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Ural_Federal_District/gis_osm_transport_free_1.shp')
Volga_Federal_District_buildings=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Volga_Federal_District/gis_osm_buildings_a_free_1.shp')
Volga_Federal_District_places=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Volga_Federal_District/gis_osm_places_free_1.shp')
Volga_Federal_District_pois=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Volga_Federal_District/gis_osm_pois_free_1.shp')
Volga_Federal_District_traffic=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Volga_Federal_District/gis_osm_traffic_free_1.shp')
Volga_Federal_District_transport=gpd.read_file('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/Volga_Federal_District/gis_osm_transport_free_1.shp')

# %%
Central_Federal_District_buildings
Central_Federal_District_places
Central_Federal_District_pois
Central_Federal_District_traffic
Central_Federal_District_transport
Crimean_Federal_District_buildings
Crimean_Federal_District_places
Crimean_Federal_District_pois
Crimean_Federal_District_traffic
Crimean_Federal_District_transport
Far_Eastern_Federal_District_buildings
Far_Eastern_Federal_District_places
Far_Eastern_Federal_District_pois
Far_Eastern_Federal_District_traffic
Far_Eastern_Federal_District_transport
North_Caucasus_Federal_District_buildings
North_Caucasus_Federal_District_places
North_Caucasus_Federal_District_pois
North_Caucasus_Federal_District_traffic
North_Caucasus_Federal_District_transport
Northwestern_Federal_District_buildings
Northwestern_Federal_District_places
Northwestern_Federal_District_pois
Northwestern_Federal_District_traffic
Northwestern_Federal_District_transport
Siberian_Federal_District_buildings
Siberian_Federal_District_places
Siberian_Federal_District_pois
Siberian_Federal_District_traffic
Siberian_Federal_District_transport
South_Federal_District_buildings
South_Federal_District_places
South_Federal_District_pois
South_Federal_District_traffic
South_Federal_District_transport
Ural_Federal_District_buildings
Ural_Federal_District_places
Ural_Federal_District_pois
Ural_Federal_District_traffic
Ural_Federal_District_transport
Volga_Federal_District_buildings
Volga_Federal_District_places
Volga_Federal_District_pois
Volga_Federal_District_traffic
Volga_Federal_District_transport

# %%
#все здания
buildings = pd.concat([pd.DataFrame(Central_Federal_District_buildings),
           pd.DataFrame(Crimean_Federal_District_buildings),
           pd.DataFrame(Far_Eastern_Federal_District_buildings),
           pd.DataFrame(North_Caucasus_Federal_District_buildings),
           pd.DataFrame(Northwestern_Federal_District_buildings),
           pd.DataFrame(Siberian_Federal_District_buildings),
           pd.DataFrame(South_Federal_District_buildings),
           pd.DataFrame(Ural_Federal_District_buildings),
           pd.DataFrame(Volga_Federal_District_buildings)          
          ])

# %%
#все локации
places = pd.concat([pd.DataFrame(Central_Federal_District_places),
           pd.DataFrame(Crimean_Federal_District_places),
           pd.DataFrame(Far_Eastern_Federal_District_places),
           pd.DataFrame(North_Caucasus_Federal_District_places),
           pd.DataFrame(Northwestern_Federal_District_places),
           pd.DataFrame(Siberian_Federal_District_places),
           pd.DataFrame(South_Federal_District_places),
           pd.DataFrame(Ural_Federal_District_places),
           pd.DataFrame(Volga_Federal_District_places)          
          ])

# %%
#объекты
pois = pd.concat([pd.DataFrame(Central_Federal_District_pois),
           pd.DataFrame(Crimean_Federal_District_pois),
           pd.DataFrame(Far_Eastern_Federal_District_pois),
           pd.DataFrame(North_Caucasus_Federal_District_pois),
           pd.DataFrame(Northwestern_Federal_District_pois),
           pd.DataFrame(Siberian_Federal_District_pois),
           pd.DataFrame(South_Federal_District_pois),
           pd.DataFrame(Ural_Federal_District_pois),
           pd.DataFrame(Volga_Federal_District_pois)          
          ])

# %%
#транспортные объекты
transport = pd.concat([pd.DataFrame(Central_Federal_District_transport),
           pd.DataFrame(Crimean_Federal_District_transport),
           pd.DataFrame(Far_Eastern_Federal_District_transport),
           pd.DataFrame(North_Caucasus_Federal_District_transport),
           pd.DataFrame(Northwestern_Federal_District_transport),
           pd.DataFrame(Siberian_Federal_District_transport),
           pd.DataFrame(South_Federal_District_transport),
           pd.DataFrame(Ural_Federal_District_transport),
           pd.DataFrame(Volga_Federal_District_transport)          
          ])

# %%
#траффик (парковки)
traffic = pd.concat([pd.DataFrame(Central_Federal_District_traffic),
           pd.DataFrame(Crimean_Federal_District_traffic),
           pd.DataFrame(Far_Eastern_Federal_District_traffic),
           pd.DataFrame(North_Caucasus_Federal_District_traffic),
           pd.DataFrame(Northwestern_Federal_District_traffic),
           pd.DataFrame(Siberian_Federal_District_traffic),
           pd.DataFrame(South_Federal_District_traffic),
           pd.DataFrame(Ural_Federal_District_traffic),
           pd.DataFrame(Volga_Federal_District_traffic)          
          ])

# %%
#сохранение в csv на всякий случай
buildings.to_csv(path+'датафреймы OSM (строения, объекты)/buildings.csv', index = False, header = True) 
places.to_csv(path+'датафреймы OSM (строения, объекты)/places.csv', index = False, header = True) 
pois.to_csv(path+'датафреймы OSM (строения, объекты)/pois.csv', index = False, header = True) 
transport.to_csv(path+'датафреймы OSM (строения, объекты)/transport.csv', index = False, header = True) 
traffic.to_csv(path+'датафреймы OSM (строения, объекты)/traffic.csv', index = False, header = True)

# %% [markdown]
# # Данные собраны. Предобработка данных

# %% [markdown]
# ### Строения

# %%
buildings = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/датафреймы OSM (строения, объекты)/buildings.csv')
pois = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/датафреймы OSM (строения, объекты)/pois.csv')
places = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/датафреймы OSM (строения, объекты)/places.csv')
traffic = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/датафреймы OSM (строения, объекты)/traffic.csv')
transport = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/датафреймы OSM (строения, объекты)/transport.csv')

# %%
buildings.groupby('type').count().sort_values('geometry', ascending = False).head(50)
build_types =['house', 'detached', 'apartments', 'residential', 'retail', 'commercial', 'office','train_station']

# %%
buildings_cleared = buildings[buildings['type'].isin(build_types)]

# %%
pois.groupby('fclass').count().sort_values('geometry', ascending = False).head(5)
pois_type = ['convenience', 'cafe', 'supermarket','atm','bank','fast_food','clothes',
 'mobile_phone_shop', 'restaurant','pharmacy','clothes','vending_any','shoe_shop','vending_parking','cinema']

# %% [markdown]
# ### Объекты

# %%
pois_cleared = pois[pois['fclass'].isin(pois_type)]

# %%
transport.groupby('fclass').count()

['airport','bus_stop','railway_halt','railway_station','']
# Out:
# ['airport', 'bus_stop', 'railway_halt', 'railway_station', '']

# %% [markdown]
# ### Транспортные объекты

# %%
transport.groupby('fclass').count()

transport_type = ['airport','bus_stop','railway_halt','railway_station','tram_stop']

# %%
transport_cleared = transport[transport['fclass'].isin(transport_type)]

# %% [markdown]
# ### Парковки

# %%
traffic_cleared = traffic[traffic['fclass'].isin(['parking','parking_underground'])]

# %%
#places

# %% [markdown]
# ### Импорт трейна т теста

# %%
df_test = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/test.csv')
df_train = pd.read_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/train.csv')

# %%
df_test['test_train_flag'] = 'test'
df_train['test_train_flag']= 'train'

# %%
df_test.head(5)
# Out:
#    Unnamed: 0      id  atm_group                                 address  \
# 0           0  8096.0     5478.0  D. 97, UL. KIROVA         NOVOKUZNETSK
# 1           1  2570.0     3185.5  UL. SERGEJA MAKEEVA       MOSKVA
# 2           2  2428.0     3185.5  UL.NAHIMOVA, DOM 33       VILJUCHINSK
# 3           3  2799.0     3185.5  MKR 3 D 13B SHAR          SHARYPOVO
# 4           4   250.0     1942.0  29 CHICHERINA STR.        CHELYABINSK
#
#                                          address_rus        lat        long  \
# 0  улица Кирова, 97, Новокузнецк, Кемеровская обл...  53.757824   87.159786
# 1                                                NaN        NaN         NaN
# 2  улица Нахимова, 33, жилой район Рыбачий, Вилюч...  52.918598  158.514038
# 3  3-й микрорайон, Шарыпово, Красноярский край, Р...  55.533496   89.178148
# 4      улица Чичерина, 29, Челябинск, Россия, 454128  55.179216   61.297729
#
#   test_train_flag
# 0            test
# 1            test
# 2            test
# ...

# %%
df_train.head(5)
# Out:
#    Unnamed: 0      id  atm_group                                 address  \
# 0           0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1           1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2           2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3           3  8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4           4    37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
#
#                                          address_rus        lat        long  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Ленинградский проспект, 76А, Москва, Россия, 1...  55.805827   37.515146
# 4  Гвардейская площадь, 2, Норильск, Красноярский...  69.343541   88.211228
#
#      target test_train_flag
# 0  0.011500           train
# 1  0.029710           train
# ...

# %%
#обьедниняю тест и треин
df_all  = pd.concat([df_train.drop(['target'], axis =1), df_test])
df_all.head(5)
# Out:
#    Unnamed: 0      id  atm_group                                 address  \
# 0           0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1           1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2           2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3           3  8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4           4    37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
#
#                                          address_rus        lat        long  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Ленинградский проспект, 76А, Москва, Россия, 1...  55.805827   37.515146
# 4  Гвардейская площадь, 2, Норильск, Красноярский...  69.343541   88.211228
#
#   test_train_flag
# 0           train
# 1           train
# 2           train
# ...

# %%
#420 банкоматов без координат.
df_all[df_all['lat'].isnull()].count()
# Out:
# Unnamed: 0         420
# id                 420
# atm_group          420
# address            420
# address_rus          0
# lat                  0
# long                 0
# test_train_flag    420
# dtype: int64

# %%
#Пока удалю иx
df_all2 = df_all[~(df_all['lat'].isnull())]

# %%
#переименнновываю широту
df_all2 = df_all2.rename(columns={'long':'lng'})

# %%
#удаляю столбец unnamed:0
df_all2= df_all2.drop('Unnamed: 0',axis=1)

# %%
df_all2
# Out:
#           id  atm_group                                 address  \
# 0     8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1     8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2     8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3     8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4       37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
# ...      ...        ...                                     ...
# 2499  7805.0     5478.0  D. 12, PROEZD ZAREVYI     MOSKVA G
# 2500  7395.0     5478.0  D. 2B, UL. MIRA           SOCHI G
# 2501  3339.0     8083.0  KARMANITSKIY, 9        Moskva
# 2502   675.0     1942.0  3A SHARAPOVSKIY WAY       MYTISHCHI
# 2503  3135.0     8083.0  24 KM MKAD, VLADENIE 1 Moskva
#
#                                             address_rus        lat  \
# 0     улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995
# 1     Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353
# ...

# %%
df_all2_geometry = gpd.GeoDataFrame(df_all2, geometry=gpd.points_from_xy(df_all2.lng, df_all2.lat))

# %%
df_all2_geometry.head()
# Out:
#        id  atm_group                                 address  \
# 0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3  8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4    37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
#
#                                          address_rus        lat         lng  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Ленинградский проспект, 76А, Москва, Россия, 1...  55.805827   37.515146
# 4  Гвардейская площадь, 2, Норильск, Красноярский...  69.343541   88.211228
#
#   test_train_flag                    geometry
# 0           train  POINT (142.73832 46.94100)
# 1           train  POINT (142.75335 46.93735)
# ...

# %%
df_all2_geometry.geometry = df_all2_geometry.geometry.set_crs('EPSG:4326').to_crs('EPSG:3857')

# %%
gs = gpd.GeoSeries.from_wkt(pois_cleared['geometry'])
pois_cleared = gpd.GeoDataFrame(pois_cleared, geometry=gs)
pois_cleared.geometry = pois_cleared.geometry.set_crs('EPSG:4326').to_crs('EPSG:3857')

# %%
gs = gpd.GeoSeries.from_wkt(buildings_cleared['geometry'])
buildings_cleared = gpd.GeoDataFrame(buildings_cleared, geometry=gs)
buildings_cleared.geometry = buildings_cleared.geometry.set_crs('EPSG:4326').to_crs('EPSG:3857')

# %%
gs = gpd.GeoSeries.from_wkt(transport_cleared['geometry'])
transport_cleared = gpd.GeoDataFrame(transport_cleared, geometry=gs)
transport_cleared.geometry = transport_cleared.geometry.set_crs('EPSG:4326').to_crs('EPSG:3857')

# %%
gs = gpd.GeoSeries.from_wkt(traffic_cleared['geometry'])
traffic_cleared = gpd.GeoDataFrame(traffic_cleared, geometry=gs)
traffic_cleared.geometry = traffic_cleared.geometry.set_crs('EPSG:4326').to_crs('EPSG:3857')

# %%
#ближайшая дистанция до любого банка
#df_all2_geometry = df_all2_geometry\
#.sjoin_nearest(pois_cleared[pois_cleared['fclass']=='bank'], how = 'left', max_distance=1000,distance_col='distance_to_bank')
#df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)

# %%
#ближайшая дистанция до любого банкомата
#df_all_pois = df_all_pois\
#.sjoin_nearest(pois_cleared[pois_cleared['fclass']=='atm'], how = 'left', max_distance=1000,distance_col='distance_to_atm')
#df_all_pois.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)

# %%
#cделать ближайшую дистанцию до любого банка, банкомата росбанка, сбербанка, альфабанка?

# %%
for i in set(pois_cleared['fclass']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(pois_cleared[pois_cleared['fclass']==i], how = 'left', max_distance=10000,distance_col='distance_to_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
for i in set(['Сбербанк','Росбанк', 'Альфа-Банк','ВТБ']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(pois_cleared[(pois_cleared['fclass']=='bank')&(pois_cleared['name']==i)], how = 'left', max_distance=10000,distance_col='distance_to_bank_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
for i in set(['Сбербанк','Росбанк', 'Альфа-Банк','ВТБ']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(pois_cleared[(pois_cleared['fclass']=='atm')&(pois_cleared['name']==i)], how = 'left', max_distance=10000,distance_col='distance_to_atm_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
for i in set(buildings_cleared['type']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(buildings_cleared[buildings_cleared['type']==i], how = 'left', max_distance=10000,distance_col='distance_to_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','type','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
for i in set(transport_cleared['fclass']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(transport_cleared[transport_cleared['fclass']==i], how = 'left', max_distance=100000,distance_col='distance_to_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
for i in set(traffic_cleared['fclass']):
    df_all2_geometry = df_all2_geometry\
    .sjoin_nearest(traffic_cleared[traffic_cleared['fclass']==i], how = 'left', max_distance=10000,distance_col='distance_to_'+i)
    df_all2_geometry.drop(['index_right','osm_id','code','fclass','name'], axis = 1, inplace =True)
df_all2_geometry.drop_duplicates( keep='first', inplace=True)

# %%
df_all2_geometry.head(5)
# Out:
#        id  atm_group                                 address  \
# 0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3  8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4    37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
#
#                                          address_rus        lat         lng  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Ленинградский проспект, 76А, Москва, Россия, 1...  55.805827   37.515146
# 4  Гвардейская площадь, 2, Норильск, Красноярский...  69.343541   88.211228
#
#   test_train_flag                          geometry  distance_to_fast_food  \
# 0           train  POINT (15889556.988 5932448.267)            1101.997929
# ...

# %%
df_all2_geometry.columns
# Out:
# Index(['id', 'atm_group', 'address', 'address_rus', 'lat', 'lng',
#        'test_train_flag', 'geometry', 'distance_to_fast_food',
#        'distance_to_clothes', 'distance_to_vending_parking',
#        'distance_to_cafe', 'distance_to_pharmacy', 'distance_to_atm',
#        'distance_to_cinema', 'distance_to_shoe_shop', 'distance_to_bank',
#        'distance_to_supermarket', 'distance_to_restaurant',
#        'distance_to_mobile_phone_shop', 'distance_to_convenience',
#        'distance_to_vending_any', 'distance_to_bank_Сбербанк',
#        'distance_to_bank_ВТБ', 'distance_to_bank_Альфа-Банк',
#        'distance_to_bank_Росбанк', 'distance_to_atm_Сбербанк',
#        'distance_to_atm_ВТБ', 'distance_to_atm_Альфа-Банк',
#        'distance_to_atm_Росбанк', 'distance_to_retail',
#        'distance_to_residential', 'distance_to_office',
#        'distance_to_commercial', 'distance_to_detached',
#        'distance_to_train_station', 'distance_to_apartments',
# ...

# %%
len(df_all2_geometry)
# Out:
# 8345

# %% [markdown]
# # Добавляю новые фичи: количество многоквартирных домов, банков и банкоматов в радиусе 100 м

# %%
#перевожу обратно координаты точки из метров в координаты
df_all2_geometry.geometry = df_all2_geometry.geometry.set_crs('EPSG:3857').to_crs('EPSG:4326')

# %%
#cоздаю копию датафрейма, чтобы сделать полигон
df_copy = df_all2_geometry.copy()

# %%
#cоздаю полигон в формате h3
import h3pandas
df_copy = pd.DataFrame(df_copy)
df_copy = df_copy.h3.geo_to_h3(9)

# %%
#вытягиваю размеры полигона из формата h3
df_copy['val']= 9
df_geometry =  df_copy[['id','val']].h3.h3_to_geo_boundary().reset_index()[['id', 'geometry']]

# %%
#перевожу обратно координаты точки из метров в координаты
buildings_cleared.geometry =  buildings_cleared.geometry.set_crs('EPSG:3857').to_crs('EPSG:4326')
pois_cleared.geometry =  pois_cleared.geometry.set_crs('EPSG:3857').to_crs('EPSG:4326')

# %%
#добавляю новую фичу кол-во многоквартирных домов в диаметре 200м
df_geometry_2 = gpd.sjoin(df_geometry, buildings_cleared[ buildings_cleared['type'] =='apartments'][['type','geometry']], how='left', op='intersects')
df_all2_geometry = df_all2_geometry.merge(df_geometry_2.groupby('id').type.count().reset_index().rename(columns = {'type':'cnt_apart_200m'}))
# Out:
# C:\Program Files\Anaconda\envs\osm\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
df_geometry_2 = gpd.sjoin(df_geometry, pois_cleared[pois_cleared['fclass']=='bank'][['fclass','geometry']], how='left', op='intersects')
df_all2_geometry = df_all2_geometry.merge(df_geometry_2.groupby('id').fclass.count().reset_index().rename(columns = {'fclass':'cnt_banks_200m'}))
# Out:
# C:\Program Files\Anaconda\envs\osm\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
df_geometry_2 = gpd.sjoin(df_geometry, pois_cleared[pois_cleared['fclass']=='atm'][['fclass','geometry']], how='left', op='intersects')
df_all2_geometry = df_all2_geometry.merge(df_geometry_2.groupby('id').fclass.count().reset_index().rename(columns = {'fclass':'cnt_atm_200m'}))
# Out:
# C:\Program Files\Anaconda\envs\osm\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
#запись в файл
df_all2_geometry.to_csv('C:/Users/User/Desktop/ВШЭ/Курсы/Годовой проект/Данные/data_with_OSM.csv', header = True)

# %%
df_all2_geometry.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 8345 entries, 0 to 8344
# Data columns (total 48 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               8345 non-null   float64
#  1   atm_group                        8345 non-null   float64
#  2   address                          8345 non-null   object
#  3   address_rus                      8345 non-null   object
#  4   lat                              8345 non-null   float64
#  5   lng                              8345 non-null   float64
#  6   test_train_flag                  8345 non-null   object
#  7   geometry                         8345 non-null   geometry
#  8   distance_to_fast_food            7627 non-null   float64
#  9   distance_to_clothes              7656 non-null   float64
#  10  distance_to_vending_parking      2006 non-null   float64
# ...
